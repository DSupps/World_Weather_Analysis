# %%
# Create a new set of 2,000 random latitudes and longitudes.

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
import time

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        time.sleep(60)
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | jalu
# Processing Record 4 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 1 | diu
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | shelburne
# Processing Record 9 of Set 1 | the valley
# Processing Record 10 of Set 1 | margate
# Processing Record 11 of Set 1 | komsomolskiy
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | boussu
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | conceicao do araguaia
# Processing Record 18 of Set 1 | sao filipe
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | aykhal
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | xichang
# Processing Record 24 of Set 1 | lapeer
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | ketchikan
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | cockburn town
# Processing Record 30 of Set 1 | desaguadero
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | sao gabriel da cachoeira
# Processing Record 35 of Set 1 | haines junction
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | beziers
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | sibut
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | marsa matruh
# Processing Record 46 of Set 1 | sisimiut
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 1 | gazojak
# Processing Record 50 of Set 1 | petropavl
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | arlit
# Processing Record 4 of Set 2 | dicabisagan
# Processing Record 5 of Set 2 | rantoul
# Processing Record 6 of Set 2 | yumen
# Processing Record 7 of Set 2 | mabaruma
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | waingapu
# Processing Record 11 of Set 2 | souillac
# Processing Record 12 of Set 2 | yulara
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | porto nacional
# Processing Record 16 of Set 2 | hambantota
# Processing Record 17 of Set 2 | dingle
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | kedougou
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | prado
# Processing Record 23 of Set 2 | bosaso
# Processing Record 24 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | sao joao da barra
# Processing Record 27 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | geraldton
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | santa lucia
# Processing Record 35 of Set 2 | rio gallegos
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | kloulklubed
# Processing Record 38 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 2 | belen
# Processing Record 40 of Set 2 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | alugan
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | pierre
# Processing Record 45 of Set 2 | khorixas
# Processing Record 46 of Set 2 | jiazi
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 2 | lucapa
# Processing Record 50 of Set 2 | faya
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | hami
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | lokosovo
# Processing Record 5 of Set 3 | velez-malaga
# Processing Record 6 of Set 3 | cody
# Processing Record 7 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | lipari
# Processing Record 11 of Set 3 | saldanha
# Processing Record 12 of Set 3 | pauini
# Processing Record 13 of Set 3 | vestmannaeyjar
# Processing Record 14 of Set 3 | gravdal
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | nalut
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | westport
# Processing Record 19 of Set 3 | hays
# Processing Record 20 of Set 3 | la tuque
# Processing Record 21 of Set 3 | enid
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | tiznit
# Processing Record 24 of Set 3 | hamilton
# Processing Record 25 of Set 3 | cabo san lucas
# Processing Record 26 of Set 3 | prabumulih
# Processing Record 27 of Set 3 | nadvoitsy
# Processing Record 28 of Set 3 | quelimane
# Processing Record 29 of Set 3 | kashi
# Processing Record 30 of Set 3 | kahului
# Processing Record 31 of Set 3 | piacabucu
# Processing Record 32 of Set 3 | santa rosa
# Processing Record 33 of Set 3 | luderitz
# Processing Record 34 of Set 3 | san patricio
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | aklavik
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | bandarbeyla
# Processing Record 39 of Set 3 | khasan
# Processing Record 40 of Set 3 | sola
# Processing Record 41 of Set 3 | faanui
# Processing Record 42 of Set 3 | cape town
# Processing Record 43 of Set 3 | launceston
# Processing Record 44 of Set 3 | provideniya
# Processing Record 45 of Set 3 | kungurtug
# Processing Record 46 of Set 3 | labytnangi
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | qaanaaq
# Processing Record 50 of Set 3 | salalah
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | leczyca
# Processing Record 3 of Set 4 | port macquarie
# Processing Record 4 of Set 4 | pedro ii
# Processing Record 5 of Set 4 | kenai
# Processing Record 6 of Set 4 | salvador
# Processing Record 7 of Set 4 | tazmalt
# Processing Record 8 of Set 4 | panalingaan
# Processing Record 9 of Set 4 | coihaique
# Processing Record 10 of Set 4 | asau
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | rocha
# Processing Record 13 of Set 4 | windhoek
# Processing Record 14 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | pingdu
# Processing Record 17 of Set 4 | huntsville
# Processing Record 18 of Set 4 | pershotravneve
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | pensacola
# Processing Record 21 of Set 4 | richards bay
# Processing Record 22 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 4 | kathu
# Processing Record 24 of Set 4 | lincoln
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | canutama
# Processing Record 27 of Set 4 | lavrentiya
# Processing Record 28 of Set 4 | constantine
# Processing Record 29 of Set 4 | leningradskiy
# Processing Record 30 of Set 4 | comodoro rivadavia
# Processing Record 31 of Set 4 | mogadishu
# Processing Record 32 of Set 4 | nurota
# Processing Record 33 of Set 4 | butaritari
# Processing Record 34 of Set 4 | kawalu
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | bud
# Processing Record 37 of Set 4 | port hardy
# Processing Record 38 of Set 4 | batsfjord
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | ilulissat
# Processing Record 41 of Set 4 | pemba
# Processing Record 42 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 4 | surgut
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | peachland
# Processing Record 46 of Set 4 | kortkeros
# Processing Record 47 of Set 4 | chikoy
# City not found. Skipping...
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | victoria
# Processing Record 50 of Set 4 | port said
# Processing Record 1 of Set 5 | razole
# Processing Record 2 of Set 5 | mar del plata
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | pouebo
# Processing Record 5 of Set 5 | boueni
# Processing Record 6 of Set 5 | whitehorse
# Processing Record 7 of Set 5 | jizan
# Processing Record 8 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | mwene-ditu
# Processing Record 11 of Set 5 | abha
# Processing Record 12 of Set 5 | kupang
# Processing Record 13 of Set 5 | bredasdorp
# Processing Record 14 of Set 5 | saint george
# Processing Record 15 of Set 5 | matara
# Processing Record 16 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | sikonge
# Processing Record 18 of Set 5 | husavik
# Processing Record 19 of Set 5 | guerrero negro
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | kormilovka
# Processing Record 22 of Set 5 | smithers
# Processing Record 23 of Set 5 | khash
# Processing Record 24 of Set 5 | soavinandriana
# Processing Record 25 of Set 5 | ponta do sol
# Processing Record 26 of Set 5 | svetlogorsk
# Processing Record 27 of Set 5 | san quintin
# Processing Record 28 of Set 5 | manggar
# Processing Record 29 of Set 5 | maniitsoq
# Processing Record 30 of Set 5 | prince rupert
# Processing Record 31 of Set 5 | chalus
# Processing Record 32 of Set 5 | nanortalik
# Processing Record 33 of Set 5 | broome
# Processing Record 34 of Set 5 | bolivar
# Processing Record 35 of Set 5 | bilibino
# Processing Record 36 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 5 | tsaratanana
# Processing Record 38 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 5 | klaksvik
# Processing Record 40 of Set 5 | fairbanks
# Processing Record 41 of Set 5 | port keats
# Processing Record 42 of Set 5 | coahuayana
# Processing Record 43 of Set 5 | gorom-gorom
# Processing Record 44 of Set 5 | udachnyy
# Processing Record 45 of Set 5 | north platte
# Processing Record 46 of Set 5 | caribou
# Processing Record 47 of Set 5 | astoria
# Processing Record 48 of Set 5 | upata
# Processing Record 49 of Set 5 | kuusankoski
# Processing Record 50 of Set 5 | sitka
# Processing Record 1 of Set 6 | grindavik
# Processing Record 2 of Set 6 | codrington
# Processing Record 3 of Set 6 | neath
# Processing Record 4 of Set 6 | san onofre
# Processing Record 5 of Set 6 | goedereede
# Processing Record 6 of Set 6 | zamora
# Processing Record 7 of Set 6 | bengkulu
# Processing Record 8 of Set 6 | voyvozh
# Processing Record 9 of Set 6 | natal
# Processing Record 10 of Set 6 | saint-louis
# Processing Record 11 of Set 6 | norman wells
# Processing Record 12 of Set 6 | tondano
# Processing Record 13 of Set 6 | hasaki
# Processing Record 14 of Set 6 | tefe
# Processing Record 15 of Set 6 | orapa
# Processing Record 16 of Set 6 | fairview
# Processing Record 17 of Set 6 | deputatskiy
# Processing Record 18 of Set 6 | namibe
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | yarada
# Processing Record 21 of Set 6 | ahipara
# Processing Record 22 of Set 6 | esperance
# Processing Record 23 of Set 6 | vyshkovo
# Processing Record 24 of Set 6 | la ronge
# Processing Record 25 of Set 6 | carroll
# Processing Record 26 of Set 6 | adrar
# Processing Record 27 of Set 6 | rantauprapat
# Processing Record 28 of Set 6 | lasem
# Processing Record 29 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 30 of Set 6 | semme
# Processing Record 31 of Set 6 | pangnirtung
# Processing Record 32 of Set 6 | dakar
# Processing Record 33 of Set 6 | vagay
# Processing Record 34 of Set 6 | bjornevatn
# Processing Record 35 of Set 6 | sao mateus
# Processing Record 36 of Set 6 | gat
# Processing Record 37 of Set 6 | mandalgovi
# Processing Record 38 of Set 6 | damara
# Processing Record 39 of Set 6 | mangan
# Processing Record 40 of Set 6 | nicoya
# Processing Record 41 of Set 6 | hangu
# Processing Record 42 of Set 6 | kruisfontein
# Processing Record 43 of Set 6 | kassala
# Processing Record 44 of Set 6 | pontian kecil
# Processing Record 45 of Set 6 | anchorage
# Processing Record 46 of Set 6 | lata
# Processing Record 47 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 48 of Set 6 | nome
# Processing Record 49 of Set 6 | conceicao da barra
# Processing Record 50 of Set 6 | cayenne
# Processing Record 1 of Set 7 | henties bay
# Processing Record 2 of Set 7 | ciudad guayana
# Processing Record 3 of Set 7 | oksfjord
# Processing Record 4 of Set 7 | ciudad bolivar
# Processing Record 5 of Set 7 | zhigansk
# Processing Record 6 of Set 7 | monrovia
# Processing Record 7 of Set 7 | bangui
# Processing Record 8 of Set 7 | belaya gora
# Processing Record 9 of Set 7 | vila franca do campo
# Processing Record 10 of Set 7 | ulaanbaatar
# Processing Record 11 of Set 7 | harper
# Processing Record 12 of Set 7 | sungairaya
# Processing Record 13 of Set 7 | praia
# Processing Record 14 of Set 7 | sanming
# Processing Record 15 of Set 7 | srednekolymsk
# Processing Record 16 of Set 7 | buta
# Processing Record 17 of Set 7 | marzuq
# Processing Record 18 of Set 7 | prince george
# Processing Record 19 of Set 7 | hualmay
# Processing Record 20 of Set 7 | wanning
# Processing Record 21 of Set 7 | brae
# Processing Record 22 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 7 | selcuk
# Processing Record 24 of Set 7 | ballina
# Processing Record 25 of Set 7 | yerofey pavlovich
# Processing Record 26 of Set 7 | pocatello
# Processing Record 27 of Set 7 | half moon bay
# Processing Record 28 of Set 7 | meulaboh
# Processing Record 29 of Set 7 | riyadh
# Processing Record 30 of Set 7 | velizh
# Processing Record 31 of Set 7 | pimenta bueno
# Processing Record 32 of Set 7 | belm
# Processing Record 33 of Set 7 | ribeira grande
# Processing Record 34 of Set 7 | hovd
# Processing Record 35 of Set 7 | prince albert
# Processing Record 36 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 7 | fukue
# Processing Record 38 of Set 7 | clyde river
# Processing Record 39 of Set 7 | vanimo
# Processing Record 40 of Set 7 | nokaneng
# Processing Record 41 of Set 7 | vao
# Processing Record 42 of Set 7 | poletayevo
# Processing Record 43 of Set 7 | jhawarian
# Processing Record 44 of Set 7 | ayan
# Processing Record 45 of Set 7 | dahanu
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | colares
# Processing Record 48 of Set 7 | tecpan
# Processing Record 49 of Set 7 | katobu
# Processing Record 50 of Set 7 | canto do buriti
# Processing Record 1 of Set 8 | college
# Processing Record 2 of Set 8 | sadsalan
# Processing Record 3 of Set 8 | mezen
# Processing Record 4 of Set 8 | laguna
# Processing Record 5 of Set 8 | namuac
# Processing Record 6 of Set 8 | te anau
# Processing Record 7 of Set 8 | isla vista
# Processing Record 8 of Set 8 | la tijera
# Processing Record 9 of Set 8 | houma
# Processing Record 10 of Set 8 | vardo
# Processing Record 11 of Set 8 | saint-augustin
# Processing Record 12 of Set 8 | tremedal
# Processing Record 13 of Set 8 | kuryk
# Processing Record 14 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 8 | tongliao
# Processing Record 17 of Set 8 | kharp
# Processing Record 18 of Set 8 | lalmohan
# Processing Record 19 of Set 8 | anadyr
# Processing Record 20 of Set 8 | ormara
# Processing Record 21 of Set 8 | bourg-les-valence
# Processing Record 22 of Set 8 | aripuana
# Processing Record 23 of Set 8 | valparaiso
# Processing Record 24 of Set 8 | nesbyen
# Processing Record 25 of Set 8 | semey
# Processing Record 26 of Set 8 | strelka
# Processing Record 27 of Set 8 | vani
# Processing Record 28 of Set 8 | vostok
# Processing Record 29 of Set 8 | alofi
# Processing Record 30 of Set 8 | vanavara
# Processing Record 31 of Set 8 | bauchi
# Processing Record 32 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 8 | pochutla
# Processing Record 34 of Set 8 | paracuru
# Processing Record 35 of Set 8 | kapit
# Processing Record 36 of Set 8 | hofn
# Processing Record 37 of Set 8 | gobabis
# Processing Record 38 of Set 8 | port-cartier
# Processing Record 39 of Set 8 | aasiaat
# Processing Record 40 of Set 8 | mecca
# Processing Record 41 of Set 8 | najran
# Processing Record 42 of Set 8 | dalvik
# Processing Record 43 of Set 8 | rizhao
# Processing Record 44 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 8 | pokhara
# Processing Record 46 of Set 8 | cortes
# Processing Record 47 of Set 8 | santiago
# Processing Record 48 of Set 8 | new iberia
# Processing Record 49 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 8 | volzhsk
# Processing Record 1 of Set 9 | kikwit
# Processing Record 2 of Set 9 | kisanga
# Processing Record 3 of Set 9 | martin
# Processing Record 4 of Set 9 | fortuna
# Processing Record 5 of Set 9 | skrunda
# Processing Record 6 of Set 9 | chicama
# Processing Record 7 of Set 9 | caxito
# Processing Record 8 of Set 9 | labuhan
# Processing Record 9 of Set 9 | grand gaube
# Processing Record 10 of Set 9 | lovozero
# Processing Record 11 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 9 | verkhoyansk
# Processing Record 13 of Set 9 | nogliki
# Processing Record 14 of Set 9 | aguimes
# Processing Record 15 of Set 9 | egvekinot
# Processing Record 16 of Set 9 | roald
# Processing Record 17 of Set 9 | noumea
# Processing Record 18 of Set 9 | tazovskiy
# Processing Record 19 of Set 9 | caravelas
# Processing Record 20 of Set 9 | jelenia gora
# Processing Record 21 of Set 9 | kirakira
# Processing Record 22 of Set 9 | imbituba
# Processing Record 23 of Set 9 | mayo
# Processing Record 24 of Set 9 | vastervik
# City not found. Skipping...
# Processing Record 25 of Set 9 | port augusta
# Processing Record 26 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 9 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 28 of Set 9 | ankang
# Processing Record 29 of Set 9 | malanje
# Processing Record 30 of Set 9 | owensboro
# Processing Record 31 of Set 9 | roma
# Processing Record 32 of Set 9 | amapa
# Processing Record 33 of Set 9 | orodara
# Processing Record 34 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | la union
# Processing Record 36 of Set 9 | burnie
# Processing Record 37 of Set 9 | piracuruca
# Processing Record 38 of Set 9 | xining
# Processing Record 39 of Set 9 | mount isa
# Processing Record 40 of Set 9 | iracoubo
# Processing Record 41 of Set 9 | nouadhibou
# Processing Record 42 of Set 9 | picos
# Processing Record 43 of Set 9 | barranca
# Processing Record 44 of Set 9 | padang
# Processing Record 45 of Set 9 | bontang
# Processing Record 46 of Set 9 | severnyy
# Processing Record 47 of Set 9 | ancud
# Processing Record 48 of Set 9 | honiara
# Processing Record 49 of Set 9 | yar-sale
# Processing Record 50 of Set 9 | zyryanka
# Processing Record 1 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 2 of Set 10 | sangar
# Processing Record 3 of Set 10 | wad madani
# Processing Record 4 of Set 10 | coria
# Processing Record 5 of Set 10 | mahibadhoo
# Processing Record 6 of Set 10 | idukki
# Processing Record 7 of Set 10 | yorkton
# Processing Record 8 of Set 10 | palmer
# Processing Record 9 of Set 10 | sept-iles
# Processing Record 10 of Set 10 | abakaliki
# Processing Record 11 of Set 10 | ishigaki
# Processing Record 12 of Set 10 | tautira
# Processing Record 13 of Set 10 | katsina
# Processing Record 14 of Set 10 | ilinskoye-khovanskoye
# Processing Record 15 of Set 10 | galveston
# Processing Record 16 of Set 10 | saint-pierre
# Processing Record 17 of Set 10 | terre haute
# Processing Record 18 of Set 10 | snasa
# Processing Record 19 of Set 10 | port lincoln
# Processing Record 20 of Set 10 | quime
# Processing Record 21 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 10 | chimore
# Processing Record 23 of Set 10 | panzhihua
# Processing Record 24 of Set 10 | fare
# Processing Record 25 of Set 10 | sobolevo
# Processing Record 26 of Set 10 | sinnamary
# Processing Record 27 of Set 10 | gawler
# Processing Record 28 of Set 10 | berdyaush
# Processing Record 29 of Set 10 | agadez
# Processing Record 30 of Set 10 | san juan
# Processing Record 31 of Set 10 | seoul
# Processing Record 32 of Set 10 | barinas
# Processing Record 33 of Set 10 | iquique
# Processing Record 34 of Set 10 | ust-kuyga
# Processing Record 35 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 10 | sirnak
# Processing Record 37 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 38 of Set 10 | lebork
# Processing Record 39 of Set 10 | singaraja
# Processing Record 40 of Set 10 | beringovskiy
# Processing Record 41 of Set 10 | baherden
# Processing Record 42 of Set 10 | charlestown
# Processing Record 43 of Set 10 | kibre mengist
# Processing Record 44 of Set 10 | agadir
# Processing Record 45 of Set 10 | portland
# Processing Record 46 of Set 10 | sokolovyy
# Processing Record 47 of Set 10 | saint-leu
# Processing Record 48 of Set 10 | souris
# Processing Record 49 of Set 10 | sungaipenuh
# Processing Record 50 of Set 10 | buala
# Processing Record 1 of Set 11 | kokopo
# Processing Record 2 of Set 11 | ariquemes
# Processing Record 3 of Set 11 | nelson
# Processing Record 4 of Set 11 | isangel
# Processing Record 5 of Set 11 | vershino-shakhtaminskiy
# Processing Record 6 of Set 11 | manavalakurichi
# Processing Record 7 of Set 11 | sarapulka
# Processing Record 8 of Set 11 | bayan
# Processing Record 9 of Set 11 | domoni
# Processing Record 10 of Set 11 | nongan
# Processing Record 11 of Set 11 | pervomayskoye
# Processing Record 12 of Set 11 | lorengau
# Processing Record 13 of Set 11 | guarumal
# Processing Record 14 of Set 11 | oksovskiy
# Processing Record 15 of Set 11 | quatre cocos
# Processing Record 16 of Set 11 | hobyo
# Processing Record 17 of Set 11 | jiangyou
# Processing Record 18 of Set 11 | mumford
# Processing Record 19 of Set 11 | ballybofey
# Processing Record 20 of Set 11 | mattru
# Processing Record 21 of Set 11 | teya
# Processing Record 22 of Set 11 | uruguaiana
# Processing Record 23 of Set 11 | jaru
# Processing Record 24 of Set 11 | manacapuru
# Processing Record 25 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 11 | lure
# Processing Record 29 of Set 11 | havre-saint-pierre
# Processing Record 30 of Set 11 | flin flon
# Processing Record 31 of Set 11 | sapa
# Processing Record 32 of Set 11 | fallon
# Processing Record 33 of Set 11 | murray bridge
# Processing Record 34 of Set 11 | methoni
# Processing Record 35 of Set 11 | teguise
# Processing Record 36 of Set 11 | yanam
# Processing Record 37 of Set 11 | dayong
# Processing Record 38 of Set 11 | zhaoyuan
# Processing Record 39 of Set 11 | preobrazheniye
# Processing Record 40 of Set 11 | maunabo
# Processing Record 41 of Set 11 | saquarema
# Processing Record 42 of Set 11 | axim
# Processing Record 43 of Set 11 | svobodnyy
# Processing Record 44 of Set 11 | marsh harbour
# Processing Record 45 of Set 11 | varna
# Processing Record 46 of Set 11 | ambovombe
# Processing Record 47 of Set 11 | salaga
# Processing Record 48 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 49 of Set 11 | thai binh
# Processing Record 50 of Set 11 | tual
# Processing Record 1 of Set 12 | beloha
# Processing Record 2 of Set 12 | shama
# Processing Record 3 of Set 12 | poya
# Processing Record 4 of Set 12 | sinjai
# Processing Record 5 of Set 12 | gigmoto
# Processing Record 6 of Set 12 | rucar
# Processing Record 7 of Set 12 | inta
# Processing Record 8 of Set 12 | afyonkarahisar
# Processing Record 9 of Set 12 | bugasong
# Processing Record 10 of Set 12 | bani
# Processing Record 11 of Set 12 | tuatapere
# Processing Record 12 of Set 12 | yaan
# Processing Record 13 of Set 12 | birobidzhan
# Processing Record 14 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 12 | necochea
# Processing Record 16 of Set 12 | acapulco
# Processing Record 17 of Set 12 | oistins
# Processing Record 18 of Set 12 | cartagena
# Processing Record 19 of Set 12 | kinkala
# Processing Record 20 of Set 12 | palu
# Processing Record 21 of Set 12 | pedernales
# Processing Record 22 of Set 12 | quirinopolis
# Processing Record 23 of Set 12 | barbate
# Processing Record 24 of Set 12 | berlevag
# Processing Record 25 of Set 12 | kamyshlov
# Processing Record 26 of Set 12 | chapais
# Processing Record 27 of Set 12 | touros
# Processing Record 28 of Set 12 | vulcan
# Processing Record 29 of Set 12 | opuwo
# Processing Record 30 of Set 12 | dongsheng
# Processing Record 31 of Set 12 | sovkhoznyy
# Processing Record 32 of Set 12 | maragheh
# Processing Record 33 of Set 12 | sao felix do xingu
# Processing Record 34 of Set 12 | thinadhoo
# Processing Record 35 of Set 12 | poltavka
# Processing Record 36 of Set 12 | naze
# Processing Record 37 of Set 12 | kiunga
# Processing Record 38 of Set 12 | sabha
# Processing Record 39 of Set 12 | shitanjing
# Processing Record 40 of Set 12 | coquimbo
# Processing Record 41 of Set 12 | emerald
# Processing Record 42 of Set 12 | nadadores
# Processing Record 43 of Set 12 | lunino
# Processing Record 44 of Set 12 | daru
# Processing Record 45 of Set 12 | road town
# Processing Record 46 of Set 12 | saint paul
# Processing Record 47 of Set 12 | darlawn
# Processing Record 48 of Set 12 | young
# Processing Record 49 of Set 12 | fort-shevchenko
# Processing Record 50 of Set 12 | acarau
# Processing Record 1 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 2 of Set 13 | truro
# Processing Record 3 of Set 13 | ugoofaaru
# Processing Record 4 of Set 13 | tura
# Processing Record 5 of Set 13 | les cayes
# Processing Record 6 of Set 13 | beitbridge
# Processing Record 7 of Set 13 | walvis bay
# Processing Record 8 of Set 13 | mackay
# Processing Record 9 of Set 13 | guarapari
# Processing Record 10 of Set 13 | zhangye
# Processing Record 11 of Set 13 | manta
# Processing Record 12 of Set 13 | barra do garcas
# Processing Record 13 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 13 | svit
# Processing Record 15 of Set 13 | novikovo
# Processing Record 16 of Set 13 | taybad
# Processing Record 17 of Set 13 | havelock
# Processing Record 18 of Set 13 | gijon
# Processing Record 19 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 20 of Set 13 | alice springs
# Processing Record 21 of Set 13 | borogontsy
# Processing Record 22 of Set 13 | baghmara
# Processing Record 23 of Set 13 | galesong
# Processing Record 24 of Set 13 | porto novo
# Processing Record 25 of Set 13 | del rio
# Processing Record 26 of Set 13 | normandin
# Processing Record 27 of Set 13 | misratah
# Processing Record 28 of Set 13 | poum
# Processing Record 29 of Set 13 | weligama
# Processing Record 30 of Set 13 | takaka
# Processing Record 31 of Set 13 | gezing
# Processing Record 32 of Set 13 | lebedinyy
# Processing Record 33 of Set 13 | paamiut
# Processing Record 34 of Set 13 | elk city
# Processing Record 35 of Set 13 | igarka
# Processing Record 36 of Set 13 | aswan
# Processing Record 37 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 13 | korla
# Processing Record 39 of Set 13 | stromness
# Processing Record 40 of Set 13 | ingham
# Processing Record 41 of Set 13 | bangassou
# Processing Record 42 of Set 13 | concarneau
# Processing Record 43 of Set 13 | susaki
# Processing Record 44 of Set 13 | avera
# Processing Record 45 of Set 13 | myitkyina
# Processing Record 46 of Set 13 | bobrovka
# Processing Record 47 of Set 13 | orbetello
# Processing Record 48 of Set 13 | pervomayskiy
# Processing Record 49 of Set 13 | collie
# Processing Record 50 of Set 13 | baboua
# City not found. Skipping...
# Processing Record 1 of Set 14 | epinal
# Processing Record 2 of Set 14 | elwood
# Processing Record 3 of Set 14 | hastings
# Processing Record 4 of Set 14 | wahlern
# Processing Record 5 of Set 14 | virginia beach
# Processing Record 6 of Set 14 | karratha
# Processing Record 7 of Set 14 | cardston
# Processing Record 8 of Set 14 | handwara
# City not found. Skipping...
# Processing Record 9 of Set 14 | norfolk
# Processing Record 10 of Set 14 | bedele
# Processing Record 11 of Set 14 | wolnzach
# Processing Record 12 of Set 14 | tamiahua
# Processing Record 13 of Set 14 | tulun
# Processing Record 14 of Set 14 | catmon
# Processing Record 15 of Set 14 | alpena
# Processing Record 16 of Set 14 | aksarka
# Processing Record 17 of Set 14 | heiligenhafen
# Processing Record 18 of Set 14 | viedma
# Processing Record 19 of Set 14 | iqaluit
# Processing Record 20 of Set 14 | moshenskoye
# Processing Record 21 of Set 14 | labuan
# Processing Record 22 of Set 14 | alyangula
# Processing Record 23 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 14 | takoradi
# Processing Record 25 of Set 14 | shelabolikha
# Processing Record 26 of Set 14 | moose factory
# Processing Record 27 of Set 14 | gogrial
# Processing Record 28 of Set 14 | pitsunda
# Processing Record 29 of Set 14 | speedway
# Processing Record 30 of Set 14 | kavaratti
# Processing Record 31 of Set 14 | north bend
# Processing Record 32 of Set 14 | shaping
# Processing Record 33 of Set 14 | kandrian
# Processing Record 34 of Set 14 | chojnice
# Processing Record 35 of Set 14 | lagoa
# Processing Record 36 of Set 14 | nyurba
# Processing Record 37 of Set 14 | nouakchott
# Processing Record 38 of Set 14 | abu samrah
# Processing Record 39 of Set 14 | luocheng
# Processing Record 40 of Set 14 | aldan
# Processing Record 41 of Set 14 | sokoto
# Processing Record 42 of Set 14 | kudahuvadhoo
# Processing Record 43 of Set 14 | pontes e lacerda
# Processing Record 44 of Set 14 | katsuura
# Processing Record 45 of Set 14 | ixtlan del rio
# Processing Record 46 of Set 14 | puerto del rosario
# Processing Record 47 of Set 14 | rio grande
# Processing Record 48 of Set 14 | toktogul
# Processing Record 49 of Set 14 | dandeli
# Processing Record 50 of Set 14 | batagay-alyta
# Processing Record 1 of Set 15 | sao paulo de olivenca
# Processing Record 2 of Set 15 | port townsend
# Processing Record 3 of Set 15 | kampong thum
# Processing Record 4 of Set 15 | dunedin
# Processing Record 5 of Set 15 | kijang
# Processing Record 6 of Set 15 | qena
# Processing Record 7 of Set 15 | phalaborwa
# Processing Record 8 of Set 15 | muret
# Processing Record 9 of Set 15 | khani
# Processing Record 10 of Set 15 | shadegan
# Processing Record 11 of Set 15 | beaverlodge
# Processing Record 12 of Set 15 | eidfjord
# Processing Record 13 of Set 15 | kununurra
# Processing Record 14 of Set 15 | padilla
# Processing Record 15 of Set 15 | sakakah
# Processing Record 16 of Set 15 | cravo norte
# Processing Record 17 of Set 15 | pozo colorado
# Processing Record 18 of Set 15 | canon city
# Processing Record 19 of Set 15 | sarakhs
# Processing Record 20 of Set 15 | catemaco
# Processing Record 21 of Set 15 | tigil
# Processing Record 22 of Set 15 | camana
# Processing Record 23 of Set 15 | taoudenni
# Processing Record 24 of Set 15 | praia da vitoria
# Processing Record 25 of Set 15 | ust-nera
# Processing Record 26 of Set 15 | bonavista
# Processing Record 27 of Set 15 | lasa
# Processing Record 28 of Set 15 | beisfjord
# Processing Record 29 of Set 15 | camacha
# Processing Record 30 of Set 15 | flagstaff
# Processing Record 31 of Set 15 | new ulm
# Processing Record 32 of Set 15 | mezcala
# Processing Record 33 of Set 15 | itarema
# Processing Record 34 of Set 15 | pushchino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Add the data to a new DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Kavieng  -2.5744  150.7967     80.76        81         100
# 1             Jalu  29.0331   21.5482     89.11        18           0
# 2              Diu  20.7141   70.9822     82.08        80           7
# 3  Arraial Do Cabo -22.9661  -42.0278     78.76        83          75
# 4           Bethel  41.3712  -73.4140     50.49        90          90
# 5        Shelburne  44.0787  -80.2041     66.67        43           5
# 6       The Valley  18.2170  -63.0578     87.66        65          75
# 7          Margate  51.3813    1.3862     53.31        79           6
# 8     Komsomolskiy  40.4272   71.7189     79.52        25          91
# 9          Rikitea -23.1203 -134.9692     75.36        71          96
#
#    Wind Speed Country      Description                 Date
# 0        9.53      PG    moderate rain  2021-05-30 19:40:51
# 1       12.91      LY        clear sky  2021-05-30 19:34:21
# 2       11.97      IN        clear sky  2021-05-30 19:40:51
# 3        8.05      BR    broken clouds  2021-05-30 19:40:52
# 4        1.99      US    moderate rain  2021-05-30 19:40:52
# 5        4.52      CA        clear sky  2021-05-30 19:36:07
# 6       16.11      AI    broken clouds  2021-05-30 19:40:52
# 7        1.99      GB        clear sky  2021-05-30 19:40:53
# 8        2.30      UZ  overcast clouds  2021-05-30 19:40:53
# 9       12.35      PF  overcast clouds  2021-05-30 19:40:53

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Kavieng      PG  -2.5744  150.7967     80.76        81
# 1               Jalu      LY  29.0331   21.5482     89.11        18
# 2                Diu      IN  20.7141   70.9822     82.08        80
# 3    Arraial Do Cabo      BR -22.9661  -42.0278     78.76        83
# 4             Bethel      US  41.3712  -73.4140     50.49        90
# ..               ...     ...      ...       ...       ...       ...
# 675        Flagstaff      US  35.1981 -111.6513     80.26        12
# 676          New Ulm      US  44.3125  -94.4605     68.50        83
# 677          Mezcala      MX  20.9333 -102.7500     89.15        15
# 678          Itarema      BR  -2.9248  -39.9167     80.01        75
# 679        Pushchino      RU  54.8339   37.6264     51.55        89
#
#      Cloudiness  Wind Speed      Description
# 0           100        9.53    moderate rain
# 1             0       12.91        clear sky
# 2             7       11.97        clear sky
# 3            75        8.05    broken clouds
# 4            90        1.99    moderate rain
# ..          ...         ...              ...
# 675          15        1.01       few clouds
# 676          90       10.36  overcast clouds
# 677          93        7.40  overcast clouds
# 678           1       13.71        clear sky
# 679         100        8.50       light rain
#
# [680 rows x 9 columns]

# %%
#8 - Export the DataFrame as a CSV file, and save it as a WeatherPy_Database.csv

output_data_file = "Weather_Database/Weatherpy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
